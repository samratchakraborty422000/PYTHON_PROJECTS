# %% [markdown]
# <a href="https://colab.research.google.com/github/samratchakraborty422000/PYTHON_PROJECTS/blob/main/Trustpilot_scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **TRUSTPILOT SCRAPER**

# %%
from flask import Flask, render_template, request,jsonify
import pandas as pd
from flask_cors import CORS,cross_origin
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
url = 'https://www.trustpilot.com/categories/clinics'

# %%
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
soup =bs(response.content, 'html.parser')
print(soup.prettify()[:5000])
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://cdn.trustpilot.net/brand-assets/1.5.0/favicons/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <meta content="Trustpilot" name="application-name"/>
#   <meta content="#1c1c1c" name="theme-color"/>
#   <link href="https://cdn.trustpilot.net/brand-assets/1.5.0/favicons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="https://cdn.trustpilot.net/brand-assets/1.5.0/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="https://cdn.trustpilot.net/brand-assets/1.5.0/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link color="#00b67a" href="https://cdn.trustpilot.net/brand-assets/1.9.0/favicons/safari-pinned-tab.svg" rel="mask-icon"/>
#   <meta content="Trustpilot" name="apple-mobile-web-app-title"/>
#   <meta content="#1c1c1c" name="msapplication-TileColor"/>
#   <script>
#    /* 'Disable' Segments Querystring API */
#         (function() {
#           var os = location.search;
#           var ns = os.length ? '?'+os.substring(1).split('&').filter(function(param){return !/^ajs_(aid|event|uid)=/i.test(param);}).join('&') : '';
#           if (typeof window.history === 'object' && os !== ns) {
#             window.history.replaceState({}, '', location.pathname + ns)
#           }
#         })();
#         /* Segment snippet */
#         !function(){var analytics=window.analytics=window.analytics||[];if(!analytics.initialize)if(analytics.invoked)window.console&&console.error&&console.error("Segment snippet included twice.");else{analytics.invoked=!0;analytics.methods=["trackSubmit","trackClick","trackLink","trackForm","pageview","identify","reset","group","track","ready","alias","debug","page","once","off","on","addSourceMiddleware","addIntegrationMiddleware","setAnonymousId","addDestinationMiddleware"];analytics.factory=function(e){return function(){var t=Array.prototype.slice.call(arguments);t.unshift(e);analytics.push(t);return analytics}};for(var e=0;e<analytics.methods.length;e++){var key=analytics.methods[e];analytics[key]=analytics.factory(key)}analytics.load=function(key,e){var t=document.createElement("script");t.type="text/javascript";t.async=!0;t.src="https://cdn.segment.com/analytics.js/v1/" + key + "/analytics.min.js";var n=document.getElementsByTagName("script")[0];n.parentNode.insertBefore(t,n);analytics._loadOptions=e};
#         analytics._writeKey="8tb69qtawc";
#         analytics.SNIPPET_VERSION="4.15.2";
#         }}();
#   </script>
#   <script>
#    (function(h){
#               h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#               h._hjSettings={hjid:391767,hjsv:6};
#             })(window);
#   </script>
#   <script class="optanon-category-C0002" src="https://static.hotjar.com/c/hotjar-391767.js?sv=6" type="text/plain">
#   </script>
#   <link crossorigin="" href="https://businessunitprofile-cdn.trustpilot.net" rel="preconnect"/>
#   <link crossorigin="" href="https://cdn.trustpilot.net/" rel="preconnect"/>
#   <link crossorigin="" href="https://api.amplitude.com/" rel="preconnect"/>
#   <link crossorigin="" href="https://user-images.trustpilot.com/" rel="preconnect"/>
#   <link href="https://cdn.segment.com/analytics.js/v1/8tb69qtawc/analytics.min.js" rel="prefetch"/>
#   <link href="https://static.hotjar.com/c/hotjar-391767.js?sv=6" rel="prefetch"/>
#   <link crossorigin="" href="https://cdn.cookielaw.org" rel="preconnect"/>
#   <link crossorigin="" href="https://geolocation.onetrust.com" rel="preconnect"/>
#   <script charset="UTF-8" data-domain-script="84cb5c09-05e4-488b-b71c-2fe171dca5e5" data-language="en-US" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="application/javascript">
#   </script>
#   <script>
#    function OptanonWrapper() {
#             var event = new CustomEvent("OptanonWrapper");
#             document.dispatchEvent(event);
#           }
#   </script>
#   <script nomodule="">
#    if (window.location.pathname !== '/error/upgradebrowser') {
#           window.location = '/error/upgradebrowser?status=browser';
#         }
#   </script>
#   <meta content="app-id=1608392803, app-argument=https://www.trustpilot.com/review/relaxedclarity.com" name="apple-itunes-app"/>
#   <title>
#    Relaxed Clarity Reviews | Read Customer Service Reviews of relaxedclarity.com
#   </title>
#   <meta content="Relaxed Clarity has 5 stars! Check out what 3,831 people have written so far, and share your own experience." name="description"/>
#   <link href="https://www.trustpilot.com/review/relaxedclarity.com" rel="canonical"/>
#   <link href="https://www.trustpilot.com/review/relaxedclarity.com?page=2" rel="next"/>
#   <link href="https://at.trustpilot.com/review/relaxedclarity.com" hreflang="de-AT" rel="alternate"/>
#   <link href="https://ch.trustpilot.com/review/relaxedclarity.com" hreflang="de-CH" rel="alternate"/>
#   <link href="https://de.trustpilot.com/review/relaxedclarity.com" hreflang="de" rel="alternate"/>
#   <link href="https://au.trustpilot.com/review/relaxedclarity.com" hreflang="en-AU" rel="alternate"/>
#   <link href="https://ca.trustpilot.com/review/relaxedclarity.com" hreflang="en-CA" rel="alternate"/>
#   <link href="https://uk.trustpilot.com/review/relaxedclarity.com" hreflang="en-GB" rel="alternate"/>
#   <link href="https://ie.trustpilot.com/review/relaxedclarity.com" hreflang="en-IE" rel="alternate"/>
#   <link href="https://nz.trustpilot.com/review/relaxedclarity.com" hreflang="en-NZ" rel="alternate"/>
#   <link href="https://www.trustpilot.com/review/relaxedclarity.com" hreflang="x-default" rel="alternate"/>
#   <link href="https://www.trustpilot.com/review/relaxedclarity.com" hreflang="en" rel="alternate"/>
#   <meta content='Relaxed Clarity is rated "Excellent" with 4.9 / 5 on Trustpilot' property="og:title"/>
#   <meta content="trustpilot:company" property="og:type"/>
#   <meta content="https://www.trustpilot.com/review/relaxedclarity.com" property="og:url"/>
#   <meta content="Trustpilot" property="og:site_name"/>
#   <meta content="Do you agree with Relaxed Clarity's TrustScore? Voice your opinion today and hear what 3,831 customers have already said." property="og:description"/>
#   <meta content="https://share.trustpilot.com/images/company-rating?locale=en-US&amp;businessUnitId=5ef1f1d5de0cb70001f4d84f&amp;preset=consumersite" property="og:image"/>
#   <meta content="1080" property="og:image:width"/>
#   <meta content="1080" property="og:image:height"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="65206056824" property="fb:app_id"/>
#   <meta content="https://share.trustpilot.com/images/company-rating?locale=en-US&amp;businessUnitId=5ef1f1d5de0cb70001f4d84f" name="twitter:image"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="@Trustpilot" name="twitter:site"/>
#   <meta content='Relaxed Clarity is rated "Excellent" with 4.9 / 5 on Trustpilot' name="twitter:title"/>
#   <meta content="Do you agree with Relaxed Clarity's TrustScore? Voice your opinion today and hear what 3,831 customers have already said." name="twitter:description"/>
#   <meta content="max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>
#   <script data-business-unit-json-ld="true" type="application/ld+json">
#    {"@context":"https://schema.org","@graph":[{"@type":"Organization","@id":"https://www.trustpilot.com/#/schema/Organization/1","name":"Trustpilot","legalName":"Trustpilot A/S","url":"https://www.trustpilot.com","description":"Read reviews. Write reviews. Find companies.","sameAs":["https://en.wikipedia.org/wiki/Trustpilot","https://www.facebook.com/Trustpilot/","https://www.instagram.com/trustpilot/","https://www.linkedin.com/company/trustpilot","https://twitter.com/Trustpilot","https://www.youtube.com/c/trustpilotreviews"],"logo":{"@id":"https://www.trustpilot.com/#/schema/ImageObject/Logo/1"},"email":"support@trustpilot.com","address":{"@type":"PostalAddress","@id":"https://www.trustpilot.com/#/schema/PostalAddress/DK","streetAddress":"Pilestræde 58, 5th floor","addressLocality":"Copenhagen","addressCountry":"DK","postalCode":"1112 København"}},{"@type":"ImageObject","@id":"https://www.trustpilot.com/#/schema/ImageObject/Logo/1","url":"https://cdn.trustpilot.net/brand-assets/1.5.0/favicons/android-chrome-512x512.png","contentUrl":"https://cdn.trustpilot.net/brand-assets/1.5.0/favicons/android-chrome-512x512.png","width":{"@type":"QuantitativeValue","value":512,"unitCode":"E37","unitText":"pixel"},"height":{"@type":"QuantitativeValue","value":512,"unitCode":"E37","unitText":"pixel"},"caption":"Trustpilot Logo","name":"Trustpilot"},{"@type":"WebSite","@id":"https://www.trustpilot.com/#/schema/WebSite/1","url":"https://www.trustpilot.com/","name":"Trustpilot (en-US)","description":"We're all about consumer reviews. Get the real inside story from shoppers like you. Read, write and share reviews on Trustpilot today.","publisher":{"@id":"https://www.trustpilot.com/#/schema/Organization/1"},"copyrightHolder":{"@id":"https://www.trustpilot.com/#/schema/Organization/1"},"potentialAction":[{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https://www.trustpilot.com/search?query={search_term_string}"},"query-input":"required name=search_term_string"}],"inLanguage":"en-US"},{"@type":"WebPage","@id":"https://www.trustpilot.com/review/relaxedclarity.com","url":"https://www.trustpilot.com/review/relaxedclarity.com","name":"Relaxed Clarity Reviews","description":"Relaxed Clarity has 5 stars! Check out what 3,831 people have written so far, and share your own experience.","isPartOf":{"@id":"https://www.trustpilot.com/#/schema/WebSite/1"},"inLanguage":"en-US","breadcrumb":{"@id":"https://www.trustpilot.com/review/relaxedclarity.com/#/schema/BreadcrumbList/1"},"about":{"@id":"https://www.trustpilot.com/#/schema/Organization/relaxedclarity.com"},"mainEntity":{"@id":"https://www.trustpilot.com/#/schema/Organization/relaxedclarity.com"},"primaryImageOfPage":{"@id":"https://www.trustpilot.com/#/schema/ImageObject/relaxedclarity.com"},"hasPart":{"@id":"https://www.trustpilot.com/#/schema/DataSet/relaxedclarity.com/1"}},{"@type":"BreadcrumbList","@id":"https://www.trustpilot.com/review/relaxedclarity.com/#/schema/BreadcrumbList/1","itemListElement":[{"@type":"ListItem","position":1,"name":"Home","item":"https://www.trustpilot.com/","sameAs":"https://www.trustpilot.com/"},{"@type":"ListItem","position":2,"name":"Health & Medical","item":"https://www.trustpilot.com/categories/health_medical","sameAs":"https://www.trustpilot.com/categories/health_medical"},{"@type":"ListItem","position":3,"name":"Clinics","item":"https://www.trustpilot.com/categories/clinics","sameAs":"https://www.trustpilot.com/categories/clinics"},{"@type":"ListItem","position":4,"name":"Alternative Medicine Practitioner","item":"https://www.trustpilot.com/categories/alternative_medicine_practitioner","sameAs":"https://www.trustpilot.com/categories/alternative_medicine_practitioner"},{"@type":"ListItem","position":5,"name":"Relaxed Clarity Reviews","item":{"@id":"https://www.trustpilot.com/review/relaxedclarity.com"}}]},{"@type":"ImageObject","@id":"https://www.trustpilot.com/#/schema/ImageObject/relaxedclarity.com","url":"https://s3-eu-west-1.amazonaws.com/tpd/ ...
#   </script>
#   <script data-business-unit-json-ld-dataset="true" type="application/ld+json">
#    {"@context":["https://schema.org",{"csvw":"http://www.w3.org/ns/csvw#"}],"@graph":{"@type":"Dataset","@id":"https://www.trustpilot.com/#/schema/DataSet/relaxedclarity.com/1","name":"Relaxed Clarity","description":"Bar chart review and ratings distribution for Relaxed Clarity, provided by Trustpilot.","publisher":{"@id":"https://www.trustpilot.com/#/schema/Organization/1"},"about":{"@id":"https://www.trustpilot.com/#/schema/Organization/relaxedclarity.com"},"mainEntity":{"@type":"csvw:Table","csvw:tableSchema":{"csvw:columns":[{"csvw:name":"1 star","csvw:datatype":"integer","csvw:cells":[{"csvw:value":"37","csvw:notes":["1%"]}]},{"csvw:name":"2 stars","csvw:datatype":"integer","csvw:cells":[{"csvw:value":"20","csvw:notes":["1%"]}]},{"csvw:name":"3 stars","csvw:datatype":"integer","csvw:cells":[{"csvw:value":"39","csvw:notes":["1%"]}]},{"csvw:name":"4 stars","csvw:datatype":"integer","csvw:cells":[{"csvw:value":"151","csvw:notes":["4%"]}]},{"csvw:name":"5 stars","csvw:datatype":"integer","csvw:cells":[{"csvw:value":"3584","csvw:notes":["93%"]}]},{"csvw:name":"Total","csvw:datatype":"integer","csvw:cells":[{"csvw:value":"3831","csvw:notes":["100%"]}]}]}}}}
#   </script>
#   <meta content="59" name="next-head-count"/>
#   <link as="style" href="https://businessunitprofile-cdn.trustpilot.net/businessunitprofile-consumersite/_next/static/css/96753e8af8d12abc.css" rel="preload"/>
#   <link data-n-g="" href="https://businessunitprofile-cdn.trustpilot.net/businessunitprofile-consumersite/_next/static/css/96753e8af8d12abc.css" rel="stylesheet"/>
#   <link as="style" href="https://businessunitprofile-cdn.trustpilot.net/businessunitprofile-consumersite/_next/static/css/c7010fc3d84e63c4.css" rel="preload"/>
#   <link data-n-p="" href="https://businessunitprofile-cdn.trustpilot.net/businessunitprofile-consumersite/_next/static/css/c7010fc3d84e63c4.css" rel="stylesheet"/>
#   <link as="style" href="https://businessunitprofile-cdn.trustpilot.net/businessunitprofile-consumersite/_next/static/css/0efb379eafb3f421.css" rel="preload"/>
#   <link data-n-p="" href="https://businessunitprofile-cdn.trustpilot.net/businessunitprofile-consumersite/_next/static/css/0efb379eafb3f421.css" rel="stylesheet"/>
#   <link as="style" href="https://businessunitprofile-cdn.trustpilot.net/businessunitprofile-consumersite/_next/static/css/58219d0e839d6bf1.css" rel="preload"/>
#   <link data-n-p="" href="https://businessunitprofile-cdn.trustpilot.net/businessunitprofile-consumersite/_next/static/css/58219d0e839d6bf1.css" rel="stylesheet"/>
#   <noscript data-n-css="">
#   </noscript>
#   <script defer="" nomodule="" src="https://businessunitprofile-cdn.trustpilot.net/businessunitprofile-consumersite/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js">
#   </script>
#   <script defer="" src="https://businessunitprofile-cdn.trustpilot.net/businessunitprofile-consumersite/_next/static/chunks/webpack-e87588a77a8eaecb.js">
#   </script>
#   <script defer="" src="https://businessunitprofile-cdn.trustpilot.net/businessunitprofile-consumersite/_next/static/chunks/framework-560765ab0625ba27.js">
#   </script>
#   <script defer="" src="https://businessunitprofile-cdn.trustpilot.net/businessunitprofile-consumersite/_next/static/chunks/main-8811b8802601568d.js">
#   </script>
#   <script defer="" src="https://businessunitprofile-cdn.trustpilot.net/businessunitprofile-consumersite/_next/static/chunks/pages/_app-42fbd1642b61843f.js">
#   </script>
#   <script defer="" src="https://businessunitprofile-cdn.trustpilot.net/businessunitprofile-consumersite/_next/static/chunks/1664-b254ce174e3c2839.js">
#   </script>
#   <script defer="" src="https://businessunitprofile-cdn.trustpilot.net/businessunitprofile-consumersite/_next/static/chunks/847-fc199d9605dd4b8c.js">
#   </script>
#   <script defer="" src="https://businessunitprofile-cdn.trustpilot.net/businessunitprofile-consumersite/_next/static/chunks/5675-fc81dfddc6b3ffdc.js">
#   </script>
#   <script defer="" src="https://businessunitprofile-cdn.trustpilot.net/businessunitprofile-consumersite/_next/static/chunks/5400-0675adb3ec957ed9.js">
#   </script>
#   <script defer="" src="https://businessunitprofile-cdn.trustpilot.net/businessunitprofile-consumersite/_next/static/chunks/7825-b512ca8deba0b26a.js">
#   </script>
#   <script defer="" src="https://businessunitprofile-cdn.trustpilot.net/businessunitprofile-consumersite/_next/static/chunks/8764-75c51dbf68058559.js">
#   </script>
#   <script defer="" src="https://businessunitprofile-cdn.trustpilot.net/businessunitprofile-consumersite/_next/static/chunks/6811-b48440e75c604443.js">
#   </script>
#   <script defer="" src="https://businessunitprofile-cdn.trustpilot.net/businessunitprofile-consumersite/_next/static/chunks/7363-ddf51fe748676184.js">
#   </script>
#   <script defer="" src="https://businessunitprofile-cdn.trustpilot.net/businessunitprofile-consumersite/_next/static/chunks/9423-4053c85b304365f0.js">
#   </script>
#   <script defer="" src="https://businessunitprofile-cdn.trustpilot.net/businessunitprofile-consumersite/_next/static/chunks/8611-596f82813fe629ac.js">
#   </script>
#   <script defer="" src="https://businessunitprofile-cdn.trustpilot.net/businessunitprofile-consumersite/_next/static/chunks/9899-f81ef6e296fce896.js">
#   </script>
#   <script defer="" src="https://businessunitprofile-cdn.trustpilot.net/businessunitprofile-consumersite/_next/static/chunks/5128-876c33b800f53e3b.js">
#   </script>
#   <script defer="" src="https://businessunitprofile-cdn.trustpilot.net/businessunitprofile-consumersite/_next/static/chunks/7581-a7180d18ebfc742b.js">
#   </script>
#   <script defer="" src="https://businessunitprofile-cdn.trustpilot.net/businessunitprofile-consumersite/_next/static/chunks/pages/review/%5BbusinessUnit%5D-15fd33bc0325af2e.js">
#   </script>
#   <script defer="" src="https://businessunitprofile-cdn.trustpilot.net/businessunitprofile-consumersite/_next/static/businessunitprofile-consumersite-7281/_buildManifest.js">
#   </script>
#   <script defer="" src="https://businessunitprofile-cdn.trustpilot.net/businessunitprofile-consumersite/_next/static/businessunitprofile-consumersite-7281/_ssgManifest.js">
#   </script>
#  </head>
#  <body>
#   <div data-reactroot="" id="__next">
#    <div class="theme-provider_themeProvider__MkYcR theme-provider_theme-default__IISCt" data-constellation-theme="default">
#     <div class="theme-provider_themeProvider__MkYcR theme-provider_theme-default__IISCt" data-constellation-theme="default">
#      <div class="layout_wrapper__s2pss">
#       <div class="section-theme-provider_theme-black__InpVD" data-constellation-section-theme="black">
#        <header class="styles_header__dNzk0">
#         <div class="styles_headerInner__EmLcd" data-navigation="true">
#          <a class="link_internal__7XN06 link_wrapper__5ZJEx styles_logo__PkLy8" data-company-logo-link="true" href="/" name="company-logo" target="_self">
#           <img alt="Trustpilot reviews" src="https://cdn.trustpilot.net/brand-assets/1.1.0/logo-white.svg" width="140"/>
#          </a>
#          <div class="styles_midSection__jsFhX">
#           <div class="search-desktop_searchWithAutoCompleteWrapper___WXpW section-theme-provider_theme-default__zZfHS" data-constellation-section-theme="default">
#            <form autocomplete="off" class="search-desktop_searchWithAutoComplete__CLWER">
#             <div class="search-desktop_searchForm____um1">
#              <div class="search-desktop_iconWrapperDesktop__wxRLm">
#               <svg class="icon_icon__ECGRl icon_appearance-default___4uy_" height="20px" viewbox="0 0 16 16" width="20px" xmlns="http://www.w3.org/2000/svg">
#                <path clip-rule="evenodd" d="M3 6.75a3.75 3.75 0 1 1 7.5 0 3.75 3.75 0 0 1-7.5 0ZM6.75 2a4.75 4.75 0 1 0 2.987 8.444l3.91 3.91.707-.708-3.91-3.91A4.75 4.75 0 0 0 6.75 2Z" fill-rule="evenodd">
#                </path>
#               </svg>
#              </div>
#              <input class="search-desktop_searchInputField__CHV3l" data-header-search-field="true" name="query" placeholder="Search for a company or category…" type="search" value=""/>
#             </div>
#            </form>
#           </div>
#          </div>
#          <button aria-label="Search" class="search-button_wrapper__22ENQ styles_button__P_ISf styles_mobile__T6WU6" data-header-search-button="true" type="button">
#           <svg class="icon_icon__ECGRl icon_appearance-action__9bJa5" fill="inherit" height="24px" viewbox="0 0 16 16" width="24px" xmlns="http://www.w3.org/2000/svg">
#            <path clip-rule="evenodd" d="M3 6.75a3.75 3.75 0 1 1 7.5 0 3.75 3.75 0 0 1-7.5 0ZM6.75 2a4.75 4.75 0 1 0 2.987 8.444l3.91 3.91.707-.708-3.91-3.91A4.75 4.75 0 0 0 6.75 2Z" fill-rule="evenodd">
#            </path>
#           </svg>
#          </button>
#          <button aria-label="Open menu" class="styles_menu__oBlC_ styles_button__P_ISf styles_mobile__T6WU6" data-header-menu="true">
#           <span class="styles_line__kJGW2 styles_top__y0Pt7">
#           </span>
#           <span class="styles_line__kJGW2 styles_middle__85Xgu">
#           </span>
#           <span class="styles_line__kJGW2 styles_bottom__LRKKA">
#           </span>
#          </button>
#          <a class="link_internal__7XN06 link_wrapper__5ZJEx styles_headerLink__L1R6L styles_desktop__qrPiX" href="/categories" target="_self">
#           <span class="typography_body-m__xgxZ_ typography_appearance-default__AAY17 styles_headerLinkInner__W_yvf">
#            Categories
#           </span>
#          </a>
#          <a class="link_internal__7XN06 link_wrapper__5ZJEx styles_headerLink__L1R6L styles_desktop__qrPiX" href="/blog" target="_self">
#           <span class="typography_body-m__xgxZ_ typography_appearance-default__AAY17 styles_headerLinkInner__W_yvf">
#            Blog
#           </span>
#          </a>
#          <a class="link_internal__7XN06 link_wrapper__5ZJEx styles_headerLink__L1R6L styles_desktop__qrPiX" data-navigation-login-desktop-link="true" href="/users/connect?redirect=" name="navigation-login-desktop" rel="nofollow" target="_self">
#           <span class="typography_body-m__xgxZ_ typography_appearance-default__AAY17 styles_headerLinkInner__W_yvf">
#            Log in
#           </span>
#          </a>
#          <a class="link_internal__7XN06 button_button__T34Lr button_m__lq0nA button_appearance-primary__wuIev link_button___108l styles_desktop__qrPiX" href="https://business.trustpilot.com?utm_medium=consumer&amp;utm_source=for_companies&amp;utm_campaign=consumer_cta" target="_self">
#           <span class="typography_heading-xxs__QKBS8 typography_appearance-inherit__D7XqR typography_disableResponsiveSizing__OuNP7">
#            For businesses
#           </span>
#          </a>
#         </div>
#         <div class="styles_wrapper__sY8AQ styles_sidePanel__MHj7K styles_mobile__T6WU6">
#          <div aria-label="Close menu" class="styles_background__yoleK" role="button">
#          </div>
#          <div class="styles_content__hG1k0">
#           <div class="styles_wrapper__ti9Ds">
#            <div class="styles_inner__LD4m2" data-navigation="true">
#             <a class="link_internal__7XN06 typography_heading-s__f7029 typography_appearance-action__9NNRY link_link__IZzHN link_underlined__OXYVM" data-navigation-login-mobile-typography="true" href="/users/connect?redirect=" rel="nofollow" target="_self">
#              Log in
#              <span class="styles_arrow__2_Iab">
#               <svg class="icon_icon__ECGRl icon_appearance-inherit__EpnEx" fill="inherit" height="16px" viewbox="0 0 12 11" width="16px" xmlns="http://www.w3.org/2000/svg">
#                <path d="M10.192 5.033 6.277 1.16 6.944.5 12 5.5l-5.056 5-.667-.66 3.915-3.873H0v-.934h10.192Z">
#                </path>
#               </svg>
#              </span>
#             </a>
#             <a class="link_internal__7XN06 typography_heading-s__f7029 typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki" href="/blog" target="_self">
#              Blog
#             </a>
#             <a class="link_internal__7XN06 typography_heading-s__f7029 typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki" href="/categories" target="_self">
#              Categories
#             </a>
#             <a class="link_internal__7XN06 button_button__T34Lr button_l__mm_bi button_appearance-primary__wuIev link_button___108l" href="https://business.trustpilot.com?utm_medium=consumer&amp;utm_source=for_companies&amp;utm_campaign=consumer_cta" target="_self">
#              <span class="typography_heading-xs__jSwUz typography_appearance-inherit__D7XqR typography_disableResponsiveSizing__OuNP7">
#               For businesses
#              </span>
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </header>
#       </div>
#       <main class="layout_content__o0ojo" role="main">
#        <div class="styles_container__AimE_">
#         <div class="styles_breadcrumbWrapper__RRwLY" data-breadcrumb-section="true">
#          <nav aria-label="Breadcrumb" class="breadcrumb_breadcrumbs__SkZLS styles_breadcrumb__X5Ynk">
#           <ol class="breadcrumb_breadcrumbList__Wa1xu">
#            <li class="breadcrumb_breadcrumb__lJO__ breadcrumb_ellipsis__9WmPs">
#             <button aria-label="Show all breadcrumbs" class="button_button__T34Lr button_l__mm_bi button_appearance-link__ANr2s breadcrumb_breadcrumbLink__p1PMo" data-breadcrumb-ellipsis-button="true" name="Breadcrumb ellipsis" title="Show all breadcrumbs" type="button">
#              <span class="typography_heading-xs__jSwUz typography_appearance-default__AAY17 typography_disableResponsiveSizing__OuNP7 button_buttonText__xmelJ">
#               <svg class="icon_icon__ECGRl icon_appearance-inherit__EpnEx" fill="inherit" height="16px" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg">
#                <path d="M2 10a2 2 0 1 0 0-4 2 2 0 0 0 0 4ZM14 10a2 2 0 1 0 0-4 2 2 0 0 0 0 4ZM10 8a2 2 0 1 1-4 0 2 2 0 0 1 4 0Z">
#                </path>
#               </svg>
#              </span>
#             </button>
#             <span class="breadcrumb_arrowIcon__elXuT">
#              <svg class="icon_icon__ECGRl icon_appearance-subtle__9l3Sf" fill="inherit" height="10px" viewbox="0 0 16 16" width="10px" xmlns="http://www.w3.org/2000/svg">
#               <path clip-rule="evenodd" d="M10.51 7.776 3.953 2.158l.65-.759 7.444 6.377-7.443 6.382-.651-.759 6.557-5.623Z" fill-rule="evenodd">
#               </path>
#              </svg>
#             </span>
#            </li>
#            <li class="breadcrumb_breadcrumb__lJO__ breadcrumb_hideWithEllipsis__Wef3t">
#             <a class="link_internal__7XN06 typography_body-s__aY15Q typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki breadcrumb_breadcrumbLink__p1PMo" href="/categories/health_medical" target="_self">
#              Health &amp; Medical
#             </a>
#             <span class="breadcrumb_arrowIcon__elXuT">
#              <svg class="icon_icon__ECGRl icon_appearance-subtle__9l3Sf" fill="inherit" height="10px" viewbox="0 0 16 16" width="10px" xmlns="http://www.w3.org/2000/svg">
#               <path clip-rule="evenodd" d="M10.51 7.776 3.953 2.158l.65-.759 7.444 6.377-7.443 6.382-.651-.759 6.557-5.623Z" fill-rule="evenodd">
#               </path>
#              </svg>
#             </span>
#            </li>
#            <li class="breadcrumb_breadcrumb__lJO__ breadcrumb_hideWithEllipsis__Wef3t">
#             <a class="link_internal__7XN06 typography_body-s__aY15Q typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki breadcrumb_breadcrumbLink__p1PMo" href="/categories/clinics" target="_self">
#              Clinics
#             </a>
#             <span class="breadcrumb_arrowIcon__elXuT">
#              <svg class="icon_icon__ECGRl icon_appearance-subtle__9l3Sf" fill="inherit" height="10px" viewbox="0 0 16 16" width="10px" xmlns="http://www.w3.org/2000/svg">
#               <path clip-rule="evenodd" d="M10.51 7.776 3.953 2.158l.65-.759 7.444 6.377-7.443 6.382-.651-.759 6.557-5.623Z" fill-rule="evenodd">
#               </path>
#              </svg>
#             </span>
#            </li>
#            <li class="breadcrumb_breadcrumb__lJO__">
#             <a class="link_internal__7XN06 typography_body-s__aY15Q typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki breadcrumb_breadcrumbLink__p1PMo" href="/categories/alternative_medicine_practitioner" target="_self">
#              Alternative Medicine Practitioner
#             </a>
#             <span class="breadcrumb_arrowIcon__elXuT">
#              <svg class="icon_icon__ECGRl icon_appearance-subtle__9l3Sf" fill="inherit" height="10px" viewbox="0 0 16 16" width="10px" xmlns="http://www.w3.org/2000/svg">
#               <path clip-rule="evenodd" d="M10.51 7.776 3.953 2.158l.65-.759 7.444 6.377-7.443 6.382-.651-.759 6.557-5.623Z" fill-rule="evenodd">
#               </path>
#              </svg>
#             </span>
#            </li>
#            <li class="breadcrumb_breadcrumb__lJO__">
#             <a aria-current="page" aria-disabled="true" class="link_internal__7XN06 link_disabled__mIxH1 typography_body-s__aY15Q typography_appearance-subtle__8_H2l link_link__IZzHN link_notUnderlined__szqki breadcrumb_breadcrumbLink__p1PMo" tabindex="-1" target="_self">
#              Relaxed Clarity
#             </a>
#            </li>
#           </ol>
#          </nav>
#         </div>
#         <div class="paper_paper__1PY90 paper_square__lJX8a card_card__lQWDv card_noPadding__D8PcU card_square___tXn9 styles_navigationContainer__kPGA_">
#          <nav class="styles_navigation__ir0Qm" data-mobile-scroll-navigation="true">
#           <button class="styles_navigationLink__GJ634">
#            Overview
#           </button>
#           <button class="styles_navigationLink__GJ634">
#            Reviews
#           </button>
#           <button class="styles_navigationLink__GJ634">
#            About
#           </button>
#          </nav>
#         </div>
#         <div style="height:auto">
#          <div class="styles_dummy__O3Cxk">
#          </div>
#          <div class="styles_wrap__bEQ8l styles_wrapperBase__O8HY_ styles_withMobilePagination__IdPoO styles_withHeader__ZC7W8">
#           <div class="paper_paper__1PY90 styles_container__wP41_">
#            <div class="styles_content__2pCRG" data-overview-section="true">
#             <div class="">
#              <section class="styles_businessInformation__6ks_E">
#               <div class="styles_summary__gEFdQ">
#                <div class="profile-image_imageWrapper__kDdWe">
#                 <a aria-labelledby="business-unit-title" class="link_internal__7XN06 link_wrapper__5ZJEx profile-image_link__V9cs6" data-business-unit-header-profile-image-link="true" href="http://www.relaxedclarity.com?utm_medium=company_profile&amp;utm_source=trustpilot&amp;utm_campaign=logo_click" name="business-unit-header-profile-image" rel="nofollow noopener" target="_blank">
#                  <picture class="business-profile-image_containmentWrapper__wu_Tp">
#                   <source srcset="https://consumersiteimages.trustpilot.net/business-units/5ef1f1d5de0cb70001f4d84f-198x149-1x.avif, https://consumersiteimages.trustpilot.net/business-units/5ef1f1d5de0cb70001f4d84f-198x149-2x.avif 2x" type="image/avif"/>
#                   <source srcset="https://consumersiteimages.trustpilot.net/business-units/5ef1f1d5de0cb70001f4d84f-198x149-1x.jpg, https://consumersiteimages.trustpilot.net/business-units/5ef1f1d5de0cb70001f4d84f-198x149-2x.jpg 2x" type="image/jpeg"/>
#                   <img alt="" class="business-profile-image_image__jCBDc" src="https://consumersiteimages.trustpilot.net/business-units/5ef1f1d5de0cb70001f4d84f-198x149-1x.jpg"/>
#                  </picture>
#                 </a>
#                </div>
#                <div class="" id="business-unit-title">
#                 <h1 class="typography_default__hIMlQ typography_appearance-default__AAY17 title_title__i9V__">
#                  <span class="typography_display-s__qOjh6 typography_appearance-default__AAY17 title_displayName__TtDDM">
#                   Relaxed Clarity
#                   <!-- -->
#                  </span>
#                  <span class="typography_body-l__KUYFJ typography_appearance-subtle__8_H2l title_rating__LANL_">
#                   Reviews
#                  </span>
#                 </h1>
#                 <span class="styles_clickable__zQWyh" role="link" tabindex="0">
#                  <span class="typography_body-l__KUYFJ typography_appearance-subtle__8_H2l styles_text__W4hWi">
#                   3,831
#                   <!-- -->
#                   <!-- -->
#                   •
#                   <!-- -->
#                   <!-- -->
#                   Excellent
#                  </span>
#                 </span>
#                 <div class="styles_container__OaEK8" data-nosnippet="false">
#                  <div class="styles_rating__uyC6m styles_clickable__uWsnU styles_rating__NPyeH" data-rating-component="true" role="link" tabindex="0">
#                   <div class="star-rating_starRating__4rrcf star-rating_medium__iN6Ty">
#                    <img alt="TrustScore 5 out of 5" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-5.svg"/>
#                   </div>
#                   <p class="typography_body-l__KUYFJ typography_appearance-subtle__8_H2l" data-rating-typography="true">
#                    4.9
#                   </p>
#                  </div>
#                  <span class="styles_tooltipWrapper__ZUQzl">
#                   <span>
#                    <svg class="icon_icon__ECGRl" fill="#6C6C85" height="16px" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg">
#                     <path clip-rule="evenodd" d="M8 1a7 7 0 1 0 0 14A7 7 0 0 0 8 1ZM0 8a8 8 0 1 1 16 0A8 8 0 0 1 0 8Z" fill-rule="evenodd">
#                     </path>
#                     <path clip-rule="evenodd" d="M7.5 7h-.75V6H8.5v5.502h.75v1h-2.5v-1h.75V7ZM6.75 4a1 1 0 1 1 2 0 1 1 0 0 1-2 0Z" fill-rule="evenodd">
#                     </path>
#                    </svg>
#                   </span>
#                  </span>
#                 </div>
#                 <span>
#                  <button class="styles_verificationLabel__kukuk">
#                   <div class="typography_body-xs__FxlLP typography_appearance-default__AAY17 typography_weight-heavy__E1LTj styles_verificationIcon___X7KO" weight="heavy">
#                    <svg class="icon_icon__ECGRl icon_appearance-positive__4px2T" fill="inherit" height="12px" viewbox="0 0 16 16" width="12px" xmlns="http://www.w3.org/2000/svg">
#                     <path class="ic-verified-user" d="M1 3a2 2 0 0 1 2-2h10a2 2 0 0 1 2 2v7.989a2 2 0 0 1-1.298 1.873l-5 1.875c-.453.17-.951.17-1.404 0l-5-1.875A2 2 0 0 1 1 10.989V3Z">
#                     </path>
#                     <path class="ic-verified-user-check" d="M11.618 6.12a.875.875 0 1 0-1.236-1.24L7.03 8.22 5.66 6.647a.875.875 0 0 0-1.32 1.15l1.768 2.03c.041.047.086.089.135.125a.875.875 0 0 0 1.364.163l4.01-3.995Z">
#                     </path>
#                    </svg>
#                    VERIFIED COMPANY
#                   </div>
#                  </button>
#                 </span>
#                 <p class="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_mobileBreadcrumb__RLRmY">
#                  In the
#                  <a class="link_internal__7XN06 typography_appearance-action__9NNRY link_link__IZzHN link_underlined__OXYVM" href="/categories/alternative_medicine_practitioner" target="_self">
#                   Alternative Medicine Practitioner
#                  </a>
#                  category
#                 </p>
#                </div>
#               </div>
#               <div class="styles_badgesWrapper__6VasU">
#                <div class="styles_badges__dbvAv" data-business-unit-header-profile-link="true">
#                 <div class="styles_cardBadge__LeaaQ">
#                  <a class="link_internal__7XN06 link_wrapper__5ZJEx" href="http://www.relaxedclarity.com?utm_medium=company_profile&amp;utm_source=trustpilot&amp;utm_campaign=domain_click" rel="nofollow noopener" target="_blank">
#                   <div class="styles_content__naP81">
#                    <div class="styles_leftSide__VobV0">
#                     <div class="styles_header__7nPK9">
#                      <svg class="icon_icon__ECGRl icon_appearance-action__9bJa5" fill="inherit" height="16px" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg">
#                       <path clip-rule="evenodd" d="M8 2H2v12h12V8h-1v5H3V3h5V2Zm2 1h2.293L7.646 7.646l.708.708L13 3.707V6h1V2h-4v1Z" fill-rule="evenodd">
#                       </path>
#                      </svg>
#                      <span class="typography_body-l__KUYFJ typography_appearance-action__9NNRY typography_weight-heavy__E1LTj styles_websiteUrl__wzSmq" weight="heavy">
#                       <span class="styles_smartEllipsisContainer__US5DI">
#                        <span class="styles_prefixOverflow__5BD8d">
#                         <span class="styles_prefix__a6Wee">
#                          relaxedcla
#                         </span>
#                        </span>
#                        <span class="styles_suffix__2BIZf">
#                         rity.com
#                        </span>
#                       </span>
#                      </span>
#                     </div>
#                     <p class="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_visitWebSiteText__pzSjw">
#                      Visit this website
#                     </p>
#                    </div>
#                    <div class="styles_iconWrapper__2Ls1T">
#                     <svg class="icon_icon__ECGRl icon_appearance-action__9bJa5" fill="inherit" height="16px" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg">
#                      <path d="M12.192 7.533 8.277 3.66 8.944 3 14 8l-5.056 5-.667-.66 3.915-3.873H2v-.934h10.192Z">
#                      </path>
#                     </svg>
#                    </div>
#                   </div>
#                  </a>
#                 </div>
#                </div>
#               </div>
#              </section>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <section class="styles_mobileInfoSection__ij86J">
#          <div class="styles_cardBadge__LeaaQ styles_row__iA6ny">
#           <a class="link_internal__7XN06 link_wrapper__5ZJEx" href="http://www.relaxedclarity.com?utm_medium=company_profile&amp;utm_source=trustpilot&amp;utm_campaign=domain_click" rel="nofollow noopener" target="_blank">
#            <div class="styles_content__naP81">
#             <div class="styles_leftSide__VobV0">
#              <div class="styles_header__7nPK9">
#               <svg class="icon_icon__ECGRl icon_appearance-action__9bJa5" fill="inherit" height="16px" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg">
#                <path clip-rule="evenodd" d="M8 2H2v12h12V8h-1v5H3V3h5V2Zm2 1h2.293L7.646 7.646l.708.708L13 3.707V6h1V2h-4v1Z" fill-rule="evenodd">
#                </path>
#               </svg>
#               <span class="typography_body-l__KUYFJ typography_appearance-action__9NNRY typography_weight-heavy__E1LTj styles_websiteUrl__wzSmq" weight="heavy">
#                <span class="styles_smartEllipsisContainer__US5DI">
#                 <span class="styles_prefixOverflow__5BD8d">
#                  <span class="styles_prefix__a6Wee">
#                   relaxedcla
#                  </span>
#                 </span>
#                 <span class="styles_suffix__2BIZf">
#                  rity.com
#                 </span>
#                </span>
#               </span>
#              </div>
#             </div>
#             <div class="styles_iconWrapper__2Ls1T">
#              <svg class="icon_icon__ECGRl icon_appearance-action__9bJa5" fill="inherit" height="16px" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg">
#               <path d="M12.192 7.533 8.277 3.66 8.944 3 14 8l-5.056 5-.667-.66 3.915-3.873H2v-.934h10.192Z">
#               </path>
#              </svg>
#             </div>
#            </div>
#           </a>
#          </div>
#          <a class="link_internal__7XN06 button_button__T34Lr button_m__lq0nA button_appearance-primary__wuIev link_button___108l styles_writeReviewButtonLink__Oc2EY" data-review-company-button-mobile-link="true" href="/evaluate/relaxedclarity.com" name="review-company-button-mobile" rel="nofollow noopener" target="_self">
#           <span class="typography_heading-xxs__QKBS8 typography_appearance-inherit__D7XqR typography_disableResponsiveSizing__OuNP7">
#            Write a review
#           </span>
#          </a>
#         </section>
#         <div class="styles_mainContent__nFxAv">
#          <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv styles_companyActivityMobile___ol_C">
#           <h3 class="typography_heading-s__f7029 typography_appearance-default__AAY17 styles_header__TqIhn">
#            Company activity
#            <a class="link_internal__7XN06 typography_body-l__KUYFJ typography_appearance-action__9NNRY link_link__IZzHN link_underlined__OXYVM styles_transparencyLink__NQzJi" data-sidebar-transparency-typography="true" href="/review/relaxedclarity.com/transparency" target="_self">
#             See all
#            </a>
#           </h3>
#           <div class="styles_carouselWrapper__exiEz styles_activityCarouselWrap__eAita">
#            <div class="styles_carousel__0ug7V styles_stickyScroll__awIPl styles_fadeOut__blLW_">
#             <div class="styles_activityCard__aqGtn">
#              <span>
#               <button class="styles_basicActivityButton__zYaaD">
#                <svg class="icon_icon__ECGRl icon_appearance-default___4uy_" height="16px" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg">
#                 <path clip-rule="evenodd" d="M5 1.25v-1H4v1H0v14.5h16V1.25h-4v-1h-1v1H8.5v-1h-1v1H5Zm-1 1H1v12.5h14V2.25h-3v1h2v10.5H2V3.25h2v-1Zm1 1v-1h2.5v1H5Zm-1 1v.5h1v-.5h2.5v.5h1v-.5H11v.5h1v-.5h1v8.5H3v-8.5h1Zm7-1v-1H8.5v1H11Z" fill-rule="evenodd">
#                 </path>
#                </svg>
#                <span>
#                 Claimed profile
#                </span>
#               </button>
#              </span>
#             </div>
#             <div class="styles_activityCard__aqGtn">
#              <span>
#               <button class="styles_basicActivityButton__zYaaD">
#                <svg class="icon_icon__ECGRl icon_appearance-default___4uy_" height="16px" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg">
#                 <path clip-rule="evenodd" d="M9.143 16 16 0 0 6.857l5.714 3.429L9.143 16ZM6 9.295l-3.815-2.29 10.683-4.578L6 9.295Zm.705.705 6.868-6.868-4.578 10.683L6.705 10Z" fill-rule="evenodd">
#                 </path>
#                </svg>
#                <span>
#                 Asks for reviews — positive or negative
#                </span>
#               </button>
#              </span>
#             </div>
#             <div class="styles_activityCard__aqGtn">
#              <span>
#               <button class="styles_basicActivityButton__zYaaD">
#                <svg class="icon_icon__ECGRl icon_appearance-default___4uy_" height="16px" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg">
#                 <path d="M8.4 2v1.143a2.9 2.9 0 0 1 2.36 2.374l-.986.166A1.9 1.9 0 0 0 7.9 4.1C6.792 4.1 6 4.806 6 5.8c0 .484.208.828.557 1.1.367.285.886.483 1.454.612.632.143 1.313.383 1.846.798.552.43.943 1.05.943 1.89 0 1.475-1.076 2.463-2.4 2.663V14h-1v-1.143A2.9 2.9 0 0 1 5 10h1a1.9 1.9 0 0 0 1.9 1.9c1.108 0 1.9-.707 1.9-1.7 0-.484-.209-.83-.557-1.101-.367-.286-.886-.483-1.453-.611h-.001c-.632-.145-1.313-.385-1.846-.8C5.392 7.26 5 6.642 5 5.8c0-1.475 1.076-2.464 2.4-2.663V2h1Z">
#                 </path>
#                 <path clip-rule="evenodd" d="M16 8A8 8 0 1 1 0 8a8 8 0 0 1 16 0Zm-1 0A7 7 0 1 1 1 8a7 7 0 0 1 14 0Z" fill-rule="evenodd">
#                 </path>
#                </svg>
#                <span>
#                 Pays for extra features
#                </span>
#               </button>
#              </span>
#             </div>
#             <div class="styles_activityCard__aqGtn">
#              <span>
#               <button class="styles_basicActivityButton__zYaaD">
#                <svg class="icon_icon__ECGRl icon_appearance-default___4uy_" height="16px" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg">
#                 <path clip-rule="evenodd" d="M9.25.975H4.246A4.25 4.25 0 0 0 2.5 9.085v3.847l3.457-3.457h.299c.049.854.4 1.664.994 2.276a3.39 3.39 0 0 0 2.432 1.036h1.332l2.861 2.945v-3.3a3.468 3.468 0 0 0 1.47-1.402 3.595 3.595 0 0 0 .413-2.355 3.54 3.54 0 0 0-1.156-2.084 3.41 3.41 0 0 0-1.16-.667A4.25 4.25 0 0 0 9.25.975Zm3.912 5.91a4.248 4.248 0 0 1-3.912 2.59H7.258c.048.596.299 1.157.71 1.58a2.39 2.39 0 0 0 1.714.732h1.754l1.439 1.48V11.76l.325-.122c.534-.2.986-.587 1.275-1.098a2.594 2.594 0 0 0 .296-1.7 2.54 2.54 0 0 0-.827-1.495 2.41 2.41 0 0 0-.782-.458ZM2.175 2.749a3.25 3.25 0 0 1 2.077-.773H9.25a3.25 3.25 0 0 1 0 6.5H5.543L3.5 10.518V8.4l-.33-.12a3.25 3.25 0 0 1-.995-5.532Z" fill-rule="evenodd">
#                 </path>
#                </svg>
#                <span>
#                 Replied to 70% of negative reviews
#                </span>
#               </button>
#              </span>
#             </div>
#             <div class="styles_activityCard__aqGtn">
#              <span>
#               <button class="styles_basicActivityButton__zYaaD">
#                <svg class="icon_icon__ECGRl icon_appearance-default___4uy_" height="16px" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg">
#                 <path clip-rule="evenodd" d="M1 8a7 7 0 1 1 14 0A7 7 0 0 1 1 8Zm7-8a8 8 0 1 0 0 16A8 8 0 0 0 8 0Zm-.5 1.75V3h1V1.75h-1ZM1.75 8.5H3v-1H1.75v1ZM13 8.5h1.25v-1H13v1ZM7.5 13v1.25h1V13h-1Zm-.043-5.59a.995.995 0 0 1 .984-.058l3.205-3.206.708.708-3.355 3.354L9 8.25a1 1 0 0 1-1.997.08l-2.07-1.693.634-.774 1.89 1.547Z" fill-rule="evenodd">
#                 </path>
#                </svg>
#                <span>
#                 Replies to negative reviews in &lt; 2 weeks
#                </span>
#               </button>
#              </span>
#             </div>
#            </div>
#           </div>
#          </div>
#          <section class="styles_reviewsContainer__3_GQw" data-business-unit-reviews-section="true" data-nosnippet="false">
#           <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv styles_locationsInfoCard__H10yA">
#            <a class="link_internal__7XN06 link_wrapper__5ZJEx styles_linkWrapper__FGueT" href="/review/relaxedclarity.com/location" target="_self">
#             <div>
#              <div class="typography_heading-xs__jSwUz typography_appearance-default__AAY17 styles_title__FICcb">
#               Locations
#               <span class="typography_heading-xs__jSwUz typography_appearance-subtle__8_H2l">
#                4
#               </span>
#              </div>
#              <p class="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l">
#               Pick a location to see its reviews
#              </p>
#             </div>
#             <svg class="icon_icon__ECGRl icon_appearance-action__9bJa5" fill="inherit" height="16px" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg">
#              <path d="M12.192 7.533 8.277 3.66 8.944 3 14 8l-5.056 5-.667-.66 3.915-3.873H2v-.934h10.192Z">
#              </path>
#             </svg>
#            </a>
#           </div>
#           <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv styles_wrapper__29alX styles_quickEvaluate__lB_nW">
#            <div class="styles_avatarWrapper__v2MSM">
#             <span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%">
#              <span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%">
#               <img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%2740%27%20height=%2740%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/>
#              </span>
#              <img alt="Your profile picture" data-nimg="intrinsic" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/>
#              <noscript>
# ...
#             <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki footer-link_footerLink__9LkR_" href="https://www.trustpilot.com/users/connect?signup=True" target="_self">
#              Sign up
#             </a>
#            </li>
#            <li>
#             <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki footer-link_footerLink__9LkR_" href="https://chrome.google.com/webstore/detail/trustpilot/meagmjlgkihmljnchdjagbcgfclobkho" rel="noopener" target="_blank">
#              Chrome App
#             </a>
#            </li>
#           </ul>
#          </section>
#          <section class="footer_section__U1AL6">
#           <h3 class="typography_heading-xs__jSwUz typography_appearance-subtle__8_H2l">
#            Businesses
#           </h3>
#           <ul class="footer_links__qMPsg">
#            <li>
#             <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki footer-link_footerLink__9LkR_" href="https://business.trustpilot.com?utm_medium=consumer&amp;utm_source=footer_link_trustpilot_business_site&amp;utm_campaign=consumer_cta" target="_self">
#              Trustpilot Business
#             </a>
#            </li>
#            <li>
#             <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki footer-link_footerLink__9LkR_" href="https://business.trustpilot.com/features?utm_medium=consumer&amp;utm_source=footer_link_trustpilot_business_site_product_tour&amp;utm_campaign=consumer_cta" target="_self">
#              Products
#             </a>
#            </li>
#            <li>
#             <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki footer-link_footerLink__9LkR_" href="https://business.trustpilot.com/pricing?utm_medium=consumer&amp;utm_source=footer_link_trustpilot_business_site_plans&amp;utm_campaign=consumer_cta" target="_self">
#              Plans &amp; Pricing
#             </a>
#            </li>
#            <li>
#             <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki footer-link_footerLink__9LkR_" href="https://businessapp.b2b.trustpilot.com/?locale=en-us&amp;utm_medium=consumer&amp;utm_source=footer_link_trustpilot_business_app_login&amp;utm_campaign=consumer_cta" rel="nofollow" target="_self">
#              Business Login
#             </a>
#            </li>
#            <li>
#             <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki footer-link_footerLink__9LkR_" href="https://business.trustpilot.com/reviews" target="_self">
#              Blog for Business
#             </a>
#            </li>
#           </ul>
#          </section>
#          <section class="footer_section__U1AL6">
#           <h3 class="typography_heading-xs__jSwUz typography_appearance-subtle__8_H2l">
#            Follow us on
#           </h3>
#           <ul class="footer_links__qMPsg footer_links--horizontal-phone__Fef4B">
#            <li class="social-media-icon-link_socialMediaIconLink__CQrTV">
#             <a aria-label="Facebook" class="link_internal__7XN06 link_wrapper__5ZJEx social-media-icon-link_link__ABaJ7" data-facebook-icon-link="true" href="https://www.facebook.com/Trustpilot/" name="Facebook-icon" rel="noopener" target="_blank" title="Facebook">
#              <svg class="icon_icon__ECGRl icon_appearance-inherit__EpnEx" fill="inherit" height="18px" viewbox="0 0 16 16" width="18px" xmlns="http://www.w3.org/2000/svg">
#               <path d="m11.469 8-.355 2.313H9.25v5.59a8 8 0 1 0-2.5 0v-5.59H4.719V8H6.75V6.237c0-2.005 1.194-3.112 3.022-3.112a12.034 12.034 0 0 1 1.79.156V5.25h-1.008a2.18 2.18 0 0 0-.179.007c-.853.07-1.125.65-1.125 1.242V8h2.219Z">
#               </path>
#              </svg>
#             </a>
#            </li>
#            <li class="social-media-icon-link_socialMediaIconLink__CQrTV">
#             <a aria-label="Twitter" class="link_internal__7XN06 link_wrapper__5ZJEx social-media-icon-link_link__ABaJ7" data-twitter-icon-link="true" href="https://twitter.com/Trustpilot" name="Twitter-icon" rel="noopener" target="_blank" title="Twitter">
#              <svg class="icon_icon__ECGRl icon_appearance-inherit__EpnEx" fill="inherit" height="18px" viewbox="0 0 16 16" width="18px" xmlns="http://www.w3.org/2000/svg">
#               <path d="M14.362 5.236c.01.141.01.282.01.425 0 4.337-3.302 9.339-9.34 9.339v-.003A9.294 9.294 0 0 1 0 13.526a6.592 6.592 0 0 0 4.858-1.36 3.287 3.287 0 0 1-3.067-2.28c.492.095 1 .076 1.482-.056A3.283 3.283 0 0 1 .64 6.612v-.041c.457.254.967.395 1.49.41A3.286 3.286 0 0 1 1.114 2.6 9.317 9.317 0 0 0 7.88 6.028a3.284 3.284 0 0 1 5.594-2.994 6.587 6.587 0 0 0 2.085-.797 3.295 3.295 0 0 1-1.443 1.816A6.53 6.53 0 0 0 16 3.536a6.668 6.668 0 0 1-1.638 1.7Z">
#               </path>
#              </svg>
#             </a>
#            </li>
#            <li class="social-media-icon-link_socialMediaIconLink__CQrTV">
#             <a aria-label="Instagram" class="link_internal__7XN06 link_wrapper__5ZJEx social-media-icon-link_link__ABaJ7" data-instagram-icon-link="true" href="https://www.instagram.com/trustpilot/" name="Instagram-icon" rel="noopener" target="_blank" title="Instagram">
#              <svg class="icon_icon__ECGRl icon_appearance-inherit__EpnEx" fill="inherit" height="18px" viewbox="0 0 16 16" width="18px" xmlns="http://www.w3.org/2000/svg">
#               <path d="M4.687.056c-.851.04-1.433.176-1.94.376-.527.205-.973.48-1.416.925a3.919 3.919 0 0 0-.92 1.418c-.197.509-.33 1.09-.368 1.942C.005 5.57-.003 5.843 0 8.015c.004 2.173.014 2.445.055 3.298.04.852.176 1.433.376 1.941.205.526.48.972.925 1.415.445.444.891.716 1.419.92.509.197 1.09.331 1.942.368.852.037 1.126.046 3.298.042 2.171-.004 2.445-.014 3.298-.054.854-.04 1.432-.177 1.94-.376.526-.206.972-.48 1.415-.925a3.92 3.92 0 0 0 .92-1.42c.197-.508.331-1.09.368-1.94.037-.855.046-1.127.042-3.3-.004-2.172-.014-2.444-.055-3.297-.04-.853-.176-1.432-.375-1.941a3.928 3.928 0 0 0-.925-1.415 3.905 3.905 0 0 0-1.419-.92c-.509-.197-1.09-.331-1.942-.368-.852-.037-1.126-.046-3.298-.042C5.812.005 5.54.014 4.687.056Zm.093 14.462c-.78-.034-1.203-.164-1.486-.272a2.49 2.49 0 0 1-.92-.597 2.465 2.465 0 0 1-.6-.918c-.11-.283-.242-.706-.279-1.486-.04-.843-.048-1.096-.053-3.232-.004-2.135.004-2.388.04-3.232.034-.779.165-1.203.273-1.485.144-.374.317-.64.597-.921a2.47 2.47 0 0 1 .918-.6c.282-.11.705-.241 1.485-.278.844-.04 1.097-.048 3.232-.053 2.136-.005 2.389.003 3.233.04.78.034 1.204.163 1.485.272.374.144.64.317.921.597.282.28.455.545.6.92.111.28.242.703.279 1.483.04.844.049 1.097.053 3.232.004 2.136-.004 2.39-.04 3.232-.035.78-.164 1.204-.273 1.487a2.48 2.48 0 0 1-.597.92c-.28.282-.545.455-.919.6-.281.11-.705.242-1.484.279-.843.04-1.096.048-3.233.053-2.136.004-2.388-.004-3.232-.041Zm6.522-10.794a.961.961 0 1 0 1.922-.004.961.961 0 0 0-1.922.004Zm-7.41 4.284a4.107 4.107 0 1 0 8.215-.016 4.107 4.107 0 0 0-8.215.016Zm1.441-.003a2.667 2.667 0 1 1 5.334-.01 2.667 2.667 0 0 1-5.334.01Z">
#               </path>
#              </svg>
#             </a>
#            </li>
#            <li class="social-media-icon-link_socialMediaIconLink__CQrTV">
#             <a aria-label="LinkedIn" class="link_internal__7XN06 link_wrapper__5ZJEx social-media-icon-link_link__ABaJ7" data-linkedin-icon-link="true" href="https://www.linkedin.com/company/trustpilot/" name="LinkedIn-icon" rel="noopener" target="_blank" title="LinkedIn">
#              <svg class="icon_icon__ECGRl icon_appearance-inherit__EpnEx" fill="inherit" height="18px" viewbox="0 0 16 16" width="18px" xmlns="http://www.w3.org/2000/svg">
#               <path d="M13.637 13.637h-2.405V9.463c0-1.231-.524-1.61-1.199-1.61-.714 0-1.414.536-1.414 1.64v4.144H6.214V5.995h2.313v1.059h.031c.233-.47 1.045-1.273 2.287-1.273 1.342 0 2.792.795 2.792 3.13v4.726ZM3.567 4.93C2.8 4.93 2.18 4.348 2.18 3.55s.62-1.382 1.387-1.382c.766 0 1.386.584 1.386 1.382 0 .798-.62 1.38-1.386 1.38Zm1.202 8.7H2.364V5.989h2.405v7.642ZM14.82 0H1.182C.529 0 0 .53 0 1.182v13.637C0 15.471.53 16 1.182 16h13.637a1.18 1.18 0 0 0 1.182-1.18V1.181C16 .529 15.47 0 14.819 0Z">
#               </path>
#              </svg>
#             </a>
#            </li>
#            <li class="social-media-icon-link_socialMediaIconLink__CQrTV">
#             <a aria-label="Youtube" class="link_internal__7XN06 link_wrapper__5ZJEx social-media-icon-link_link__ABaJ7" data-youtube-icon-link="true" href="https://www.youtube.com/c/trustpilotreviews" name="Youtube-icon" rel="noopener" target="_blank" title="Youtube">
#              <svg class="icon_icon__ECGRl icon_appearance-inherit__EpnEx" fill="inherit" height="18px" viewbox="0 0 16 16" width="18px" xmlns="http://www.w3.org/2000/svg">
#               <path d="M6.4 10.472V5.689l4.157 2.391L6.4 10.472Zm9.266-6.23a2 2 0 0 0-1.415-1.409C13.003 2.5 8 2.5 8 2.5s-5.003 0-6.251.333a2 2 0 0 0-1.415 1.41C0 5.486 0 8.08 0 8.08s0 2.594.334 3.838a2 2 0 0 0 1.415 1.41C2.997 13.66 8 13.66 8 13.66s5.003 0 6.251-.334a2 2 0 0 0 1.415-1.41C16 10.675 16 8.08 16 8.08s0-2.594-.334-3.837Z">
#               </path>
#              </svg>
#             </a>
#            </li>
#           </ul>
#          </section>
#          <div class="footer_legal__b5wpP">
#           <ul class="footer_links__qMPsg footer_linksHorizontalWhenPossible__48psW">
#            <li>
#             <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki footer-link_footerLink__9LkR_" href="https://legal.trustpilot.com" target="_self">
#              Legal
#             </a>
#            </li>
#            <li>
#             <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki footer-link_footerLink__9LkR_" href="https://legal.trustpilot.com/end-user-privacy-terms" target="_self">
#              Privacy Policy
#             </a>
#            </li>
#            <li>
#             <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki footer-link_footerLink__9LkR_" href="https://legal.trustpilot.com/for-reviewers/end-user-terms-and-conditions" target="_self">
#              Terms &amp; Conditions
#             </a>
#            </li>
#            <li>
#             <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki footer-link_footerLink__9LkR_" href="https://legal.trustpilot.com/for-reviewers/guidelines-for-reviewers" target="_self">
#              Guidelines for Reviewers
#             </a>
#            </li>
#            <li>
#             <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki footer-link_footerLink__9LkR_" href="https://status.trustpilot.com/" target="_self">
#              System status
#             </a>
#            </li>
#            <li>
#             <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki footer-link_footerLink__9LkR_" href="https://legal.trustpilot.com/for-everyone/modern-slavery-and-human-trafficking-statement" target="_self">
#              Modern Slavery Statement
#             </a>
#            </li>
#           </ul>
#           <div class="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l footer_copyrightNotice__hiLk8">
#            © 2023 Trustpilot, Inc. All rights reserved.
#           </div>
#          </div>
#         </div>
#        </div>
#       </footer>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script id="__NEXT_DATA__" type="application/json">
#    {"props":{"pageProps":{"pageUrl":"https://www.trustpilot.com/review/relaxedclarity.com","businessUnit":{"id":"5ef1f1d5de0cb70001f4d84f","displayName":"Relaxed Clarity","identifyingName":"relaxedclarity.com","numberOfReviews":3831,"trustScore":4.9,"websiteUrl":"http://www.relaxedclarity.com","websiteTitle":"relaxedclarity.com","profileImageUrl":"//s3-eu-west-1.amazonaws.com/tpd/logos/5ef1f1d5de0cb70001f4d84f/0x0.png","stars":5,"categories":[{"id":"alternative_medicine_practitioner","name":"Alternative Medicine Practitioner","rank":"1","cardinality":"9","isPrimary":true}],"breadcrumb":{"topLevelId":"health_medical","topLevelDisplayName":"Health \u0026 Medical","midLevelId":"clinics","midLevelDisplayName":"Clinics","bottomLevelId":"alternative_medicine_practitioner","bottomLevelDisplayName":"Alternative Medicine Practitioner"},"isClaimed":true,"isClosed":false,"isTemporarilyClosed":false,"locationsCount":4,"isCollectingReviews":true,"verification":{"verifiedByGoogle":false,"verifiedBusiness":true,"verifiedPaymentMethod":true,"verifiedUserIdentity":false},"hasCollectedIncentivisedReviews":false,"consumerAlert":null,"isMerged":false,"contactInfo":{"email":"info@relaxedclarity.com","address":"1006 Depot Hill Road, Suite 100","city":"Broomfield","country":"US","phone":"9704125955","zipCode":"80020"},"activity":{"isUsingPaidFeatures":true,"hasSubscription":true,"isAskingForReviews":true,"claimedDate":"2020-06-23T12:13:24.000Z","isClaimed":true,"previouslyClaimed":true,"replyBehavior":{"averageDaysToReply":7.18,"lastReplyToNegativeReview":"2022-08-09 15:42:20.512 UTC","negativeReviewsWithRepliesCount":17,"replyPercentage":70.83333333333334,"totalNegativeReviewsCount":24},"verification":{"verifiedByGoogle":false,"verifiedBusiness":true,"verifiedPaymentMethod":true,"verifiedUserIdentity":false},"hasBusinessUnitMergeHistory":false,"basiclinkRate":0,"hideBasicLinkAlert":false}},"reviews":[{"id":"63e902ac745e480021a2c0d7","filtered":false,"pending":false,"text":"Wrote an email to the inga Customer Support. They staff understood the issue right away and solved the issue quickly. I am really happy with the service that I received!","rating":5,"labels":{"merged":null,"verification":{"isVerified":false,"createdDateTime":"2023-02-12T17:15:56.000Z","reviewSourceName":"Organic","verificationSource":"invitation","verificationLevel":"not-verified","hasDachExclusion":false}},"title":"Really happy with the service","likes":0,"dates":{"experiencedDate":"2023-02-02T19:00:00.000Z","publishedDate":"2023-02-12T17:15:56.000Z","updatedDate":null},"report":null,"hasUnhandledReports":false,"consumer":{"id":"63e8f59c6447140016cec62f","displayName":"Stacy Russell","imageUrl":"https://user-images.trustpilot.com/63e8f59c6447140016cec62f/73x73.png","numberOfReviews":1,"countryCode":"GB","hasImage":true,"isVerified":false},"reply":null,"consumersReviewCountOnSameDomain":1,"consumersReviewCountOnSameLocation":1,"productReviews":[],"language":"en","location":{"id":"772079dc-f439-4f56-9622-f0099759f53a","name":"Denver","urlFormattedName":"denver"}},{"id":"6371610ab84cc27618eadba2","filtered":false,"pending":false,"text":"I have been going to Relaxed Clarity for years. Everyone there is wonderful, kind, and knowledgeable. Some of the Doctors even remember me! The renewal price is very reasonable. And I wouldn't survive the state process without Joan's help! Every year she helps me! I have moved further away from the Broomfield clinic, and I will go to no one else! If you need a red card, er, med card, go to Relaxed Clarity at Broomfield,","rating":5,"labels":{"merged":null,"verification":{"isVerified":true,"createdDateTime":"2022-11-13T23:26:34.000Z","reviewSourceName":"InvitationApi","verificationSource":"invitation","verificationLevel":"verified","hasDachExclusion":false}},"title":"Relaxed Clarity is the place to go for your red, er, Med card","likes":1,"dates":{"experiencedDate":"2022-11-11T00:00:00.000Z","publishedDate":"2022-11-13T23:26:34.000Z","updatedDate":nu ...
#   </script>
#  </body>
# </html>

# %%
clinics = soup.find_all("div",{"class":"paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_wrapper__2JOo2"})
len(clinics)
# Out:
# 20

# %%
total_num_pages = 17
clinics = []

for page_num in range(1, total_num_pages + 1):
    tmp_url = url + '?page=' + str(page_num)
    response = requests.get(tmp_url)
    soup =bs(response.content, 'html.parser')
    tmp_clinics =soup.find_all("div",{"class":"paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_wrapper__2JOo2"})
    print(f'page #{page_num}:\t{len(tmp_clinics)} results found...')
    clinics.extend(tmp_clinics)

len(clinics)
# Out:
# page #1:	20 results found...
# page #2:	20 results found...
# page #3:	20 results found...
# page #4:	20 results found...
# page #5:	20 results found...
# page #6:	20 results found...
# page #7:	20 results found...
# page #8:	20 results found...
# page #9:	20 results found...
# page #10:	20 results found...
# page #11:	20 results found...
# page #12:	20 results found...
# page #13:	20 results found...
# page #14:	20 results found...
# page #15:	20 results found...
# page #16:	20 results found...
# page #17:	17 results found...
# 337

# %%
print(clinics[0].prettify())
# Out:
# <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_wrapper__2JOo2">
#  <a class="link_internal__7XN06 link_wrapper__5ZJEx styles_linkWrapper__UWs5j" data-business-unit-card-link="true" href="/review/relaxedclarity.com" name="business-unit-card" target="_self">
#   <div class="styles_badge__Tkzsi">
#    Most relevant
#   </div>
#   <div class="styles_content__98tWf">
#    <div class="styles_logoBox__SF4DX">
#     <picture class="business-profile-image_containmentWrapper__wu_Tp">
#      <source srcset="https://consumersiteimages.trustpilot.net/business-units/5ef1f1d5de0cb70001f4d84f-198x149-1x.avif, https://consumersiteimages.trustpilot.net/business-units/5ef1f1d5de0cb70001f4d84f-198x149-2x.avif 2x" type="image/avif"/>
#      <source srcset="https://consumersiteimages.trustpilot.net/business-units/5ef1f1d5de0cb70001f4d84f-198x149-1x.jpg, https://consumersiteimages.trustpilot.net/business-units/5ef1f1d5de0cb70001f4d84f-198x149-2x.jpg 2x" type="image/jpeg"/>
#      <img alt="" class="business-profile-image_image__jCBDc" src="https://consumersiteimages.trustpilot.net/business-units/5ef1f1d5de0cb70001f4d84f-198x149-1x.jpg"/>
#     </picture>
#    </div>
#    <div class="styles_businessUnitMain__PuwB7">
#     <p class="typography_heading-xs__jSwUz typography_appearance-default__AAY17 styles_displayName__GOhL2">
#      Relaxed Clarity
#     </p>
#     <div class="styles_rating__pY5Pk">
#      <div class="star-rating_starRating__4rrcf star-rating_responsive__C9oka">
#       <img alt="TrustScore 5 out of 5" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-5.svg"/>
#      </div>
#      <p class="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_ratingText__yQ5S7">
#       <span class="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_trustScore__8emxJ">
#        <span class="styles_desktop__U5iWw">
#         TrustScore
#        </span>
#        <!-- -->
#        4.9
#       </span>
#       <span class="styles_separator__TG_uV">
#        |
#       </span>
#       3,831
#       <!-- -->
#       reviews
#      </p>
#     </div>
#     <div class="styles_metadataRow__pgwwW">
#      <span class="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_metadataItem__Qn_Q2 styles_location__ILZb0" data-business-location-typography="true">
#       Broomfield
#       <!-- -->
#       ,
#       <!-- -->
#       United States
#      </span>
#     </div>
#    </div>
#   </div>
#  </a>
#  <div class="card_cardContent__sFUOe styles_categoriesLabelsWrapper__AsHrM styles_mobile__wIl_O">
#   <div class="styles_wrapper___E6__ styles_categoriesLabels__FiWQ4">
#    <span class="typography_body-s__aY15Q typography_appearance-default__AAY17">
#     Alternative Medicine Practitioner
#    </span>
#   </div>
#  </div>
#  <hr class="divider_divider__M85e9 divider_appearance-subtle__DkHcP"/>
#  <div class="card_cardContent__sFUOe styles_footerWrapper__HMFrh">
#   <div class="styles_footer__DoJVj">
#    <span>
#     <button aria-label="Contact" class="styles_iconWrapper__Iy_ZV">
#      <svg class="icon_icon__ECGRl" fill="currentColor" height="16px" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg">
#       <path clip-rule="evenodd" d="M10.694 1.537c.217.281.415.592.593.923.321.6.59 1.287.793 2.04h1.983a7.027 7.027 0 0 0-3.37-2.963ZM14.54 5.5h-2.235c.143.789.22 1.63.22 2.5 0 .87-.077 1.711-.22 2.5h2.235c.297-.776.46-1.62.46-2.5 0-.88-.163-1.724-.46-2.5Zm-.476 6H12.08a9.655 9.655 0 0 1-.793 2.04 6.698 6.698 0 0 1-.593.923 7.027 7.027 0 0 0 3.37-2.963Zm-8.758 2.963a6.708 6.708 0 0 1-.593-.923 9.654 9.654 0 0 1-.792-2.04H1.936a7.027 7.027 0 0 0 3.37 2.963ZM1.46 10.5h2.236c-.144-.789-.22-1.63-.22-2.5 0-.87.076-1.711.22-2.5H1.46A6.984 6.984 0 0 0 1 8c0 .88.163 1.724.46 2.5Zm.476-6h1.985c.203-.753.47-1.44.792-2.04.178-.331.376-.642.593-.923A7.027 7.027 0 0 0 1.936 4.5ZM8 0a8 8 0 1 0 0 16A8 8 0 0 0 8 0M5.595 2.933c-.247.46-.461.987-.635 1.567H7.5V1.075c-.677.204-1.35.822-1.905 1.858Zm4.81 0c.247.46.462.987.635 1.567H8.5V1.075c.677.204 1.35.822 1.906 1.858ZM8.5 5.5h2.787c.153.774.238 1.616.238 2.5 0 .884-.085 1.726-.238 2.5H8.5v-5Zm0 6h2.54a8.428 8.428 0 0 1-.634 1.567c-.557 1.036-1.229 1.654-1.906 1.858V11.5Zm-1 0v3.425c-.677-.204-1.35-.822-1.905-1.858A8.426 8.426 0 0 1 4.96 11.5H7.5Zm0-1H4.713A12.91 12.91 0 0 1 4.475 8c0-.884.085-1.726.238-2.5H7.5v5Z" fill-rule="evenodd">
#       </path>
#      </svg>
#      <svg class="icon_icon__ECGRl" fill="currentColor" height="16px" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg">
#       <path clip-rule="evenodd" d="M0 2.5h16v11H0v-11Zm1.789 1L8 9.173 14.211 3.5H1.79ZM15 4.134l-7 6.393-7-6.393V12.5h14V4.134Z" fill-rule="evenodd">
#       </path>
#      </svg>
#      <svg class="icon_icon__ECGRl" fill="currentColor" height="16px" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg">
#       <g clip-path="url(#a)">
#        <path clip-rule="evenodd" d="m4.622.933.04.057.003.006L6.37 3.604l.002.003a1.7 1.7 0 0 1-.442 2.29l-.036.029c-.392.325-.627.519-.652.85-.026.364.206 1.09 1.562 2.445 1.356 1.357 2.073 1.58 2.426 1.55.318-.027.503-.252.816-.632l.057-.069a1.7 1.7 0 0 1 2.29-.442l.003.002 2.608 1.705.006.004c.204.141.454.37.649.645.188.267.376.655.31 1.09-.031.213-.147.495-.305.774a4.534 4.534 0 0 1-.715.941C14.323 15.422 13.377 16 12.1 16c-1.236 0-2.569-.483-3.877-1.246-1.315-.768-2.642-1.84-3.877-3.075C3.112 10.444 2.033 9.118 1.26 7.8.49 6.49 0 5.15 0 3.9c0-1.274.52-2.215 1.144-2.845C1.751.442 2.478.098 2.954.03c.507-.072.896.088 1.182.327.224.187.387.43.486.576Zm-1.127.191a.46.46 0 0 0-.4-.104c-.223.032-.758.25-1.24.738C1.393 2.227 1 2.924 1 3.9c0 1.001.398 2.161 1.122 3.394.72 1.226 1.74 2.486 2.932 3.678 1.19 1.19 2.45 2.204 3.673 2.918 1.23.718 2.384 1.11 3.373 1.11.949 0 1.652-.422 2.138-.914.245-.247.43-.508.556-.73.134-.237.181-.393.186-.43.01-.065-.014-.19-.139-.366a1.737 1.737 0 0 0-.396-.396l-2.59-1.693a.7.7 0 0 0-.946.19l-.011.017-.013.016-.08.098c-.261.33-.723.91-1.491.975-.841.07-1.85-.47-3.218-1.838-1.369-1.37-1.912-2.381-1.85-3.225.056-.783.638-1.25.97-1.517l.09-.072.016-.013.016-.011a.7.7 0 0 0 .191-.946l-1.694-2.59-.051-.076c-.104-.152-.182-.265-.29-.355Z" fill-rule="evenodd">
#        </path>
#       </g>
#       <defs>
#        <clippath id="a">
#         <path d="M0 0h16v16H0z">
#         </path>
#        </clippath>
#       </defs>
#      </svg>
#     </button>
#    </span>
#    <div class="styles_wrapper___E6__ styles_categoriesLabels__FiWQ4 styles_desktop__U5iWw">
#     <span class="typography_body-s__aY15Q typography_appearance-default__AAY17">
#      Alternative Medicine Practitioner
#     </span>
#    </div>
#    <button aria-controls="latest-reviews-5ef1f1d5de0cb70001f4d84f-panel" aria-expanded="false" class="styles_reviewsButton__pWKds" data-recent-reviews-toggle-button="true">
#     Latest reviews
#     <!-- -->
#     <svg class="icon_icon__ECGRl" fill="currentColor" height="16px" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg">
#      <path clip-rule="evenodd" d="m8.003 10.289 5.617-6.557.76.65-6.377 7.444L1.62 4.383l.76-.651 5.623 6.557Z" fill-rule="evenodd">
#      </path>
#     </svg>
#    </button>
#   </div>
#  </div>
#  <div aria-hidden="true" class="styles_latestReviews__1RLpK styles_hide__Urk8b" id="latest-reviews-5ef1f1d5de0cb70001f4d84f-panel">
#   <div class="styles_carouselWrapper__exiEz styles_carouselWrapper__HepHU">
#    <div class="styles_carousel__0ug7V styles_stickyScroll__awIPl styles_carousel__OumfX">
#     <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_reviewCard__QrrOb styles_reviewCardSkeleton__8OkSr">
#      <div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_short__422sg">
#       </div>
#       <div class="styles_reviewRow__ho_WO">
#        <div class="styles_skeleton___6L7B styles_round__XWrvZ">
#        </div>
#        <div class="star-rating_starRating__4rrcf star-rating_small__DUZRK">
#         <img alt="" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-0.svg"/>
#        </div>
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#      </div>
#     </div>
#     <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_reviewCard__QrrOb styles_reviewCardSkeleton__8OkSr">
#      <div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_short__422sg">
#       </div>
#       <div class="styles_reviewRow__ho_WO">
#        <div class="styles_skeleton___6L7B styles_round__XWrvZ">
#        </div>
#        <div class="star-rating_starRating__4rrcf star-rating_small__DUZRK">
#         <img alt="" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-0.svg"/>
#        </div>
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#      </div>
#     </div>
#     <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_reviewCard__QrrOb styles_reviewCardSkeleton__8OkSr">
#      <div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_short__422sg">
#       </div>
#       <div class="styles_reviewRow__ho_WO">
#        <div class="styles_skeleton___6L7B styles_round__XWrvZ">
#        </div>
#        <div class="star-rating_starRating__4rrcf star-rating_small__DUZRK">
#         <img alt="" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-0.svg"/>
#        </div>
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#      </div>
#     </div>
#     <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_reviewCard__QrrOb styles_reviewCardSkeleton__8OkSr">
#      <div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_short__422sg">
#       </div>
#       <div class="styles_reviewRow__ho_WO">
#        <div class="styles_skeleton___6L7B styles_round__XWrvZ">
#        </div>
#        <div class="star-rating_starRating__4rrcf star-rating_small__DUZRK">
#         <img alt="" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-0.svg"/>
#        </div>
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#      </div>
#     </div>
#     <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_reviewCard__QrrOb styles_reviewCardSkeleton__8OkSr">
#      <div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_short__422sg">
#       </div>
#       <div class="styles_reviewRow__ho_WO">
#        <div class="styles_skeleton___6L7B styles_round__XWrvZ">
#        </div>
#        <div class="star-rating_starRating__4rrcf star-rating_small__DUZRK">
#         <img alt="" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-0.svg"/>
#        </div>
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#      </div>
#     </div>
#     <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_reviewCard__QrrOb styles_reviewCardSkeleton__8OkSr">
#      <div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_short__422sg">
#       </div>
#       <div class="styles_reviewRow__ho_WO">
#        <div class="styles_skeleton___6L7B styles_round__XWrvZ">
#        </div>
#        <div class="star-rating_starRating__4rrcf star-rating_small__DUZRK">
#         <img alt="" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-0.svg"/>
#        </div>
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#      </div>
#     </div>
#     <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_reviewCard__QrrOb styles_reviewCardSkeleton__8OkSr">
#      <div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_short__422sg">
#       </div>
#       <div class="styles_reviewRow__ho_WO">
#        <div class="styles_skeleton___6L7B styles_round__XWrvZ">
#        </div>
#        <div class="star-rating_starRating__4rrcf star-rating_small__DUZRK">
#         <img alt="" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-0.svg"/>
#        </div>
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#      </div>
#     </div>
#     <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_reviewCard__QrrOb styles_reviewCardSkeleton__8OkSr">
#      <div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_short__422sg">
#       </div>
#       <div class="styles_reviewRow__ho_WO">
#        <div class="styles_skeleton___6L7B styles_round__XWrvZ">
#        </div>
#        <div class="star-rating_starRating__4rrcf star-rating_small__DUZRK">
#         <img alt="" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-0.svg"/>
#        </div>
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#      </div>
#     </div>
#     <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_reviewCard__QrrOb styles_reviewCardSkeleton__8OkSr">
#      <div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_short__422sg">
#       </div>
#       <div class="styles_reviewRow__ho_WO">
#        <div class="styles_skeleton___6L7B styles_round__XWrvZ">
#        </div>
#        <div class="star-rating_starRating__4rrcf star-rating_small__DUZRK">
#         <img alt="" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-0.svg"/>
#        </div>
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#      </div>
#     </div>
#     <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_reviewCard__QrrOb styles_reviewCardSkeleton__8OkSr">
#      <div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_short__422sg">
#       </div>
#       <div class="styles_reviewRow__ho_WO">
#        <div class="styles_skeleton___6L7B styles_round__XWrvZ">
#        </div>
#        <div class="star-rating_starRating__4rrcf star-rating_small__DUZRK">
#         <img alt="" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-0.svg"/>
#        </div>
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#       <div class="styles_skeleton___6L7B styles_text__TIMD_ styles_multi___arWG">
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
# </div>

# %% [markdown]
# # ***scraping customer details***

# %%
name = clinics[0].select('p.styles_displayName__GOhL2')[0].text
score = clinics[0].select('span.styles_trustScore__8emxJ')[0].text
location = clinics[0].select('span.styles_location__ILZb0')[0].text
reviews = clinics[0].select('p.styles_ratingText__yQ5S7')[0].text.split('|')[-1]
name, score, location, reviews
# Out:
# ('Relaxed Clarity',
#  'TrustScore 4.9',
#  'Broomfield,\xa0United States',
#  '3,831 reviews')

# %%
data = {
    'name': [], 
    'score': [],
    'location': [],
    'reviews': []
}

for clinic in clinics:
    data['name'].append(clinic.select('p.styles_displayName__GOhL2')[0].text)

    try:
        data['score'].append(clinic.select('span.styles_trustScore__8emxJ')[0].text)
    except:
        data['score'].append(None)

    try:
        data['location'].append(clinic.select('span.styles_location__ILZb0')[0].text)
    except:
        data['location'].append(None)

    try:
        data['reviews'].append(clinic.select('p.styles_ratingText__yQ5S7')[0].text.split('|')[-1])
    except:
        data['reviews'].append(None)

df = pd.DataFrame(data)
df.head()
# Out:
#                                name           score  \
# 0                   Relaxed Clarity  TrustScore 4.9
# 1  Compassionate Clinics of America  TrustScore 4.9
# 2                      Defy Medical  TrustScore 4.9
# 3                CannabisMD TeleMed  TrustScore 4.9
# 4                     Yaya Holistic  TrustScore 4.9
#
#                      location        reviews
# 0   Broomfield, United States  3,831 reviews
# 1  Bannockburn, United States  1,134 reviews
# 2        Tampa, United States    794 reviews
# 3   Midlothian, United States    756 reviews
# 4                        None    108 reviews

# %% [markdown]
# # **scraping reviews**

# %%
url = 'https://www.trustpilot.com/review/relaxedclarity.com'

# %%
response = requests.get(url)
soup =bs(response.content, 'html.parser')
reviews = soup.select('article')
len(reviews)
# Out:
# 20

# %%
print(reviews[0].prettify())
# Out:
# <article class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv styles_reviewCard__hcAvl " data-service-review-card-paper="true">
#  <aside aria-label="Info for Stacy Russell" class="styles_consumerInfoWrapper__KP3Ra">
#   <div class="styles_consumerDetailsWrapper__p2wdr">
#    <div class="avatar_imageWrapper__8wdWb" style="width:44px;height:44px;min-width:44px;min-height:44px">
#     <span style="box-sizing:border-box;display:inline-block;overflow:hidden;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;position:relative;max-width:100%">
#      <span style="box-sizing:border-box;display:block;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0;max-width:100%">
#       <img alt="" aria-hidden="true" src="data:image/svg+xml,%3csvg%20xmlns=%27http://www.w3.org/2000/svg%27%20version=%271.1%27%20width=%2744%27%20height=%2744%27/%3e" style="display:block;max-width:100%;width:initial;height:initial;background:none;opacity:1;border:0;margin:0;padding:0"/>
#      </span>
#      <img alt="" data-consumer-avatar-image="true" data-nimg="intrinsic" decoding="async" src="..." style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/>
#      <noscript>
#       <img alt="" data-consumer-avatar-image="true" data-nimg="intrinsic" decoding="async" loading="lazy" src="https://user-images.trustpilot.com/63e8f59c6447140016cec62f/73x73.png" style="position:absolute;top:0;left:0;bottom:0;right:0;box-sizing:border-box;padding:0;border:none;margin:auto;display:block;width:0;height:0;min-width:100%;max-width:100%;min-height:100%;max-height:100%"/>
#      </noscript>
#     </span>
#    </div>
#    <a class="link_internal__7XN06 link_wrapper__5ZJEx styles_consumerDetails__ZFieb" data-consumer-profile-link="true" href="/users/63e8f59c6447140016cec62f" name="consumer-profile" rel="nofollow" target="_self">
#     <span class="typography_heading-xxs__QKBS8 typography_appearance-default__AAY17" data-consumer-name-typography="true">
#      Stacy Russell
#     </span>
#     <div class="styles_consumerExtraDetails__fxS4S" data-consumer-reviews-count="1">
#      <span class="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l" data-consumer-reviews-count-typography="true">
#       1
#       <!-- -->
#       review
#      </span>
#      <div class="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_detailsIcon__Fo_ua" data-consumer-country-typography="true">
#       <svg class="icon_icon__ECGRl" fill="currentColor" height="14px" viewbox="0 0 16 16" width="14px" xmlns="http://www.w3.org/2000/svg">
#        <path clip-rule="evenodd" d="M3.404 1.904A6.5 6.5 0 0 1 14.5 6.5v.01c0 .194 0 .396-.029.627l-.004.03-.023.095c-.267 2.493-1.844 4.601-3.293 6.056a18.723 18.723 0 0 1-2.634 2.19 11.015 11.015 0 0 1-.234.154l-.013.01-.004.002h-.002L8 15.25l-.261.426h-.002l-.004-.003-.014-.009a13.842 13.842 0 0 1-.233-.152 18.388 18.388 0 0 1-2.64-2.178c-1.46-1.46-3.05-3.587-3.318-6.132l-.003-.026v-.068c-.025-.2-.025-.414-.025-.591V6.5a6.5 6.5 0 0 1 1.904-4.596ZM8 15.25l-.261.427.263.16.262-.162L8 15.25Zm-.002-.598a17.736 17.736 0 0 0 2.444-2.04c1.4-1.405 2.79-3.322 3.01-5.488l.004-.035.026-.105c.018-.153.018-.293.018-.484a5.5 5.5 0 0 0-11 0c0 .21.001.371.02.504l.005.035v.084c.24 2.195 1.632 4.109 3.029 5.505a17.389 17.389 0 0 0 2.444 2.024Z" fill-rule="evenodd">
#        </path>
#        <path clip-rule="evenodd" d="M8 4a2.5 2.5 0 1 0 0 5 2.5 2.5 0 0 0 0-5ZM4.5 6.5a3.5 3.5 0 1 1 7 0 3.5 3.5 0 0 1-7 0Z" fill-rule="evenodd">
#        </path>
#       </svg>
#       <span>
#        GB
#       </span>
#      </div>
#     </div>
#    </a>
#   </div>
#  </aside>
#  <hr class="divider_divider__M85e9 styles_cardDivider__42s_0 divider_appearance-subtle__DkHcP"/>
#  <section aria-disabled="false" class="styles_reviewContentwrapper__zH_9M">
#   <div class="styles_reviewHeader__iU9Px" data-service-review-rating="5">
#    <div class="star-rating_starRating__4rrcf star-rating_medium__iN6Ty">
#     <img alt="Rated 5 out of 5 stars" src="https://cdn.trustpilot.net/brand-assets/4.1.0/stars/stars-5.svg"/>
#    </div>
#    <div class="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_datesWrapper__RCEKH">
#     <time class="" data-service-review-date-time-ago="true" datetime="2023-02-12T17:15:56.000Z">
#      Feb 12, 2023
#     </time>
#    </div>
#   </div>
#   <div aria-hidden="false" class="styles_reviewContent__0Q2Tg" data-review-content="true">
#    <a class="link_internal__7XN06 typography_appearance-default__AAY17 typography_color-inherit__TlgPO link_link__IZzHN link_notUnderlined__szqki" data-review-title-typography="true" href="/reviews/63e902ac745e480021a2c0d7" rel="nofollow" target="_self">
#     <h2 class="typography_heading-s__f7029 typography_appearance-default__AAY17" data-service-review-title-typography="true">
#      Really happy with the service
#     </h2>
#    </a>
#    <p class="typography_body-l__KUYFJ typography_appearance-default__AAY17 typography_color-black__5LYEn" data-service-review-text-typography="true">
#     Wrote an email to the inga Customer Support. They staff understood the issue right away and solved the issue quickly. I am really happy with the service that I received!
#    </p>
#    <p class="typography_body-m__xgxZ_ typography_appearance-default__AAY17 typography_color-black__5LYEn" data-service-review-date-of-experience-typography="true">
#     <b class="typography_body-m__xgxZ_ typography_appearance-default__AAY17 typography_weight-heavy__E1LTj" weight="heavy">
#      Date of experience
#      <!-- -->
#      :
#     </b>
#     <!-- -->
#     February 02, 2023
#    </p>
#   </div>
#  </section>
# </article>

# %%
title = reviews[0].select_one('h2.typography_heading-s__f7029').text
time = reviews[0].select_one('time').text
body = reviews[0].select_one('p.typography_body-l__KUYFJ').text
rating = reviews[0].select_one('img')['alt'] # access the attribute as dictionary
title, time, body, rating
# Out:
# ('Really happy with the service',
#  'Feb 12, 2023',
#  'Wrote an email to the inga Customer Support. They staff understood the issue right away and solved the issue quickly. I am really happy with the service that I received!',
#  '')

# %%
reviews = []
num_pages = 173

for page_num in range(1, num_pages + 1):
    tmp_url = url + '?page=' + str(page_num)
    response = requests.get(url)
    soup = bs(response.content, 'html.parser')
    tmp_reviews = soup.select('article')
    print(f'page #{page_num}:\t{len(tmp_reviews)} results found...')
    reviews.extend(tmp_reviews)
# Out:
# page #1:	20 results found...
# page #2:	20 results found...
# page #3:	20 results found...
# page #4:	20 results found...
# page #5:	20 results found...
# page #6:	20 results found...
# page #7:	20 results found...
# page #8:	20 results found...
# page #9:	20 results found...
# page #10:	20 results found...
# page #11:	20 results found...
# page #12:	20 results found...
# page #13:	20 results found...
# page #14:	20 results found...
# page #15:	20 results found...
# page #16:	20 results found...
# page #17:	20 results found...
# page #18:	20 results found...
# page #19:	20 results found...
# page #20:	20 results found...
# page #21:	20 results found...
# page #22:	20 results found...
# page #23:	20 results found...
# page #24:	20 results found...
# page #25:	20 results found...
# page #26:	20 results found...
# page #27:	20 results found...
# page #28:	20 results found...
# page #29:	20 results found...
# page #30:	20 results found...
# page #31:	20 results found...
# page #32:	20 results found...
# page #33:	20 results found...
# page #34:	20 results found...
# page #35:	20 results found...
# page #36:	20 results found...
# page #37:	20 results found...
# page #38:	20 results found...
# page #39:	20 results found...
# page #40:	20 results found...
# page #41:	20 results found...
# page #42:	20 results found...
# page #43:	20 results found...
# page #44:	20 results found...
# page #45:	20 results found...
# page #46:	20 results found...
# page #47:	20 results found...
# page #48:	20 results found...
# page #49:	20 results found...
# page #50:	20 results found...
# page #51:	20 results found...
# page #52:	20 results found...
# page #53:	20 results found...
# page #54:	20 results found...
# page #55:	20 results found...
# page #56:	20 results found...
# page #57:	20 results found...
# page #58:	20 results found...
# page #59:	20 results found...
# page #60:	20 results found...
# page #61:	20 results found...
# page #62:	20 results found...
# page #63:	20 results found...
# page #64:	20 results found...
# page #65:	20 results found...
# page #66:	20 results found...
# page #67:	20 results found...
# page #68:	20 results found...
# page #69:	20 results found...
# page #70:	20 results found...
# page #71:	20 results found...
# page #72:	20 results found...
# page #73:	20 results found...
# page #74:	20 results found...
# page #75:	20 results found...
# page #76:	20 results found...
# page #77:	20 results found...
# page #78:	20 results found...
# page #79:	20 results found...
# page #80:	20 results found...
# page #81:	20 results found...
# page #82:	20 results found...
# page #83:	20 results found...
# page #84:	20 results found...
# page #85:	20 results found...
# page #86:	20 results found...
# page #87:	20 results found...
# page #88:	20 results found...
# page #89:	20 results found...
# page #90:	20 results found...
# page #91:	20 results found...
# page #92:	20 results found...
# page #93:	20 results found...
# page #94:	20 results found...
# page #95:	20 results found...
# page #96:	20 results found...
# page #97:	20 results found...
# page #98:	20 results found...
# page #99:	20 results found...
# page #100:	20 results found...
# page #101:	20 results found...
# page #102:	20 results found...
# page #103:	20 results found...
# page #104:	20 results found...
# page #105:	20 results found...
# page #106:	20 results found...
# page #107:	20 results found...
# page #108:	20 results found...
# page #109:	20 results found...
# page #110:	20 results found...
# page #111:	20 results found...
# page #112:	20 results found...
# page #113:	20 results found...
# page #114:	20 results found...
# page #115:	20 results found...
# page #116:	20 results found...
# page #117:	20 results found...
# page #118:	20 results found...
# page #119:	20 results found...
# page #120:	20 results found...
# page #121:	20 results found...
# page #122:	20 results found...
# page #123:	20 results found...
# page #124:	20 results found...
# page #125:	20 results found...
# page #126:	20 results found...
# page #127:	20 results found...
# page #128:	20 results found...
# page #129:	20 results found...
# page #130:	20 results found...
# page #131:	20 results found...
# page #132:	20 results found...
# page #133:	20 results found...
# page #134:	20 results found...
# page #135:	20 results found...
# page #136:	20 results found...
# page #137:	20 results found...
# page #138:	20 results found...
# page #139:	20 results found...
# page #140:	20 results found...
# page #141:	20 results found...
# page #142:	20 results found...
# page #143:	20 results found...
# page #144:	20 results found...
# page #145:	20 results found...
# page #146:	20 results found...
# page #147:	20 results found...
# page #148:	20 results found...
# page #149:	20 results found...
# page #150:	20 results found...
# page #151:	20 results found...
# page #152:	20 results found...
# page #153:	20 results found...
# page #154:	20 results found...
# page #155:	20 results found...
# page #156:	20 results found...
# page #157:	20 results found...
# page #158:	20 results found...
# page #159:	20 results found...
# page #160:	20 results found...
# page #161:	20 results found...
# page #162:	20 results found...
# page #163:	20 results found...
# page #164:	20 results found...
# page #165:	20 results found...
# page #166:	20 results found...
# page #167:	20 results found...
# page #168:	20 results found...
# page #169:	20 results found...
# page #170:	20 results found...
# page #171:	20 results found...
# page #172:	20 results found...
# page #173:	20 results found...

# %%
data = {
    'title': [],
    'body': [],
    'time': [],
    'rating': []
}

for review in reviews:
    try:
        data['title'].append(review.select_one('h2.typography_heading-s__f7029').text)
    except:
        data['title'].append(None)

    try:
        data['time'].append(review.select_one('time').text)
    except:
        data['time'].append(None)

    try:
        data['body'].append(review.select_one('p.typography_body-l__KUYFJ').text)
    except:
        data['body'].append(None)

    try:
        data['rating'].append(review.select_one('img')['alt'])
    except:
        data['rating'].append(None)

df = pd.DataFrame(data)
df.head(100)
# Out:
#                                                 title  \
# 0                       Really happy with the service
# 1   Relaxed Clarity is the place to go for your re...
# 2                                      Awesome people
# 3                  Patient Visit with Relaxed Clarity
# 4             The staff was extremely helpful when I…
# ..                                                ...
# 95                            This place is the best!
# 96                                         Convenient
# 97              My experience at Relaxed Clarity was…
# 98                                   Great experience
# 99                            My experience was great
#
#                                                  body          time  \
# 0   Wrote an email to the inga Customer Support. T...  Feb 12, 2023
# 1   I have been going to Relaxed Clarity for years...  Nov 13, 2022
# 2   Yeah you guys are awesome been awesome since I...  Nov 11, 2022
# 3   My experience was excellent for several reason...   Nov 4, 2022
# 4   The staff was extremely helpful when I called ...  Nov 24, 2022
# ..                                                ...           ...
# 95  This place is wonderful! I've been a patient s...  Oct 14, 2022
# 96  I was in pretty quick and doctor gave good adv...   Oct 9, 2022
# 97  My experience at Relaxed Clarity was wonderful...  Oct 22, 2022
# 98  Great experience. Process was very simplified ...  Oct 24, 2022
# 99  My experience was great, a little nervous goin...  Oct 21, 2022
#
#                     rating
# 0
# 1   Rated 5 out of 5 stars
# 2   Rated 5 out of 5 stars
# 3   Rated 5 out of 5 stars
# 4   Rated 5 out of 5 stars
# ..                     ...
# 95  Rated 5 out of 5 stars
# 96
# 97  Rated 5 out of 5 stars
# 98  Rated 5 out of 5 stars
# 99  Rated 5 out of 5 stars
#
# [100 rows x 4 columns]
